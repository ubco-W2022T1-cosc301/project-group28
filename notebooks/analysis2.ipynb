# %% [markdown]
# Wilfred Meyer

# %% [markdown]
# ## Research question/interests
#
# I wish to find out who the lowest ranking players are in each position.

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns



def df_clean(df):
    '''
    Removes excess columns that have no meaning to the research question
    '''
    df = df.copy().drop(['Aggression', 'Jersey Number', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Special', 'Skill Moves', 'International Reputation', 'Potential', 'Marking', 'Vision', 'Curve', 'Balance', 'Jumping', 'Reactions', 'Agility', 'Composure', 'Volleys', 'HeadingAccuracy', 'Weak Foot', 'ID', 'FKAccuracy', 'Release Clause', 'Preferred Foot', 'Photo', 'Nationality', 'Flag', 'Club Logo', 'Value', 'Wage', 'Work Rate', 'Body Type', 'Real Face', 'Joined', 'Loaned From', 'Contract Valid Until', 'Finishing'], axis=1)

    df.nunique(axis=0)
    df.describe().apply(lambda s: s.apply(lambda x: format(x,'f')))

    df.columns.unique()
    
    return df



def scatter_plot(x, y):
    '''
    Scatter plots input x and y values as column names as strings.
    '''
    df.plot(kind='scatter', x=x, y=y)



df = pd.read_csv("C:/Users/willy/COSC_301/Project/project-group28/data/raw/FIFA22_official_data.csv")

df = df_clean(df)
df.dropna(axis=0)
df.head()

# scatter_plot(x='Overall', y='Dribbling')
# scatter_plot(x='Overall', y='ShortPassing')
# scatter_plot(x='Overall', y='Crossing')
# scatter_plot(x='Overall', y='LongPassing')
# Out:
#               Name  Age  Overall                Club  \
# 0  Bruno Fernandes   26       88   Manchester United
# 1      L. Goretzka   26       87   FC Bayern München
# 2        L. Suárez   34       88  Atlético de Madrid
# 3     K. De Bruyne   30       91     Manchester City
# 4         M. Acuña   29       84          Sevilla FC
#
#                       Position Height Weight  Crossing  ShortPassing  \
# 0  <span class="pos pos18">CAM  179cm   69kg      87.0          91.0
# 1  <span class="pos pos11">LDM  189cm   82kg      75.0          86.0
# 2   <span class="pos pos24">RS  182cm   83kg      80.0          83.0
# 3  <span class="pos pos13">RCM  181cm   70kg      94.0          94.0
# 4    <span class="pos pos7">LB  172cm   69kg      87.0          82.0
#
#    Dribbling  ...  Strength  LongShots  Interceptions  Positioning  Penalties  \
# 0       83.0  ...      70.0       89.0           66.0         87.0       91.0
# ...
